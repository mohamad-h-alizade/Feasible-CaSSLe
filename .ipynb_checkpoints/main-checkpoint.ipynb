# %% [markdown]
# # Feasible CaSSLe PoC
#
# Safe experiment interface for CIFAR-100 smoke and pilot runs. Expensive training is disabled by default.

# %%
from pathlib import Path
import csv, json, os, subprocess, sys

RUN_TRAINING = False
CONFIG_PATH = 'config/feasible_cassle_cifar100_smoke.yaml'
OUTPUT_ROOT = Path('outputs/feasible_cassle')
# Set to a timestamped run directory to load that run; leave None to auto-load latest.
RESULT_DIR = None

print('cwd:', Path.cwd())
print('python:', sys.version.split()[0])
print('git:', subprocess.check_output(['git', 'rev-parse', '--short', 'HEAD'], text=True).strip())
# Out:
# cwd: /home/jovyan/TML/Project/cassle
# python: 3.11.6
# git: 51ad6cc

# %% [markdown]
# ## Configuration Loading And Device

# %%
from src.config import load_config
from src.data import cifar_task_order
from src.utils import choose_device

cfg = load_config(CONFIG_PATH)
device = choose_device(cfg['experiment'].get('device', 'auto'))
tasks = cifar_task_order(cfg['experiment']['seed'])
print('config:', cfg['experiment']['name'])
print('device:', device)
print('task sizes:', [len(t) for t in tasks])
# Out:
# config: feasible_cassle_cifar100_smoke
# device: cpu
# task sizes: [20, 20, 20, 20, 20]

# %% [markdown]
# ## Runtime Diagnostics

# %%
from src.temporal_losses import derangement

perm = derangement(16)
assert not (perm == __import__('torch').arange(16)).any()
print('derangement ok:', perm.tolist())

try:
    import pytorch_lightning
    print('pytorch_lightning available')
except ModuleNotFoundError:
    print('pytorch_lightning missing: training requires the repository dependencies from README.md')
# Out:
# derangement ok: [12, 6, 0, 11, 10, 15, 2, 14, 13, 4, 9, 8, 7, 3, 1, 5]
# pytorch_lightning available

# %% [markdown]
# ## CIFAR-100 Task Split

# %%
for i, task in enumerate(tasks):
    print(f'task {i}:', task.tolist())
# Out:
# task 0: [11, 22, 39, 23, 42, 30, 78, 81, 64, 20, 29, 79, 15, 69, 86, 63, 55, 53, 73, 68]
# task 1: [89, 67, 58, 97, 96, 92, 37, 14, 75, 51, 54, 7, 3, 6, 50, 40, 45, 4, 83, 98]
# task 2: [27, 12, 8, 99, 60, 87, 28, 5, 84, 34, 82, 16, 72, 49, 59, 31, 71, 35, 66, 76]
# task 3: [61, 17, 36, 62, 13, 2, 38, 94, 80, 19, 25, 18, 0, 1, 46, 74, 85, 91, 52, 77]
# task 4: [21, 33, 32, 88, 93, 70, 44, 47, 26, 57, 90, 95, 48, 65, 43, 10, 9, 56, 24, 41]

# %% [markdown]
# ## Train Or Reuse Shared Task-1 Checkpoint

# %%
if RUN_TRAINING:
    from src.experiments import prepare_run
    from src.trainer import train_task1
    cfg, device, run_dir, tasks = prepare_run(CONFIG_PATH)
    ckpt = train_task1(cfg, run_dir, device, tasks)
    RESULT_DIR = str(run_dir)
    print('task1 checkpoint:', ckpt)
else:
    print('skipped; set RUN_TRAINING = True to run')
# Out:
# skipped; set RUN_TRAINING = True to run

# %% [markdown]
# ## Smoke Experiment

# %%
if RUN_TRAINING:
    from src.experiments import run_smoke
    result = run_smoke(CONFIG_PATH)
    RESULT_DIR = result['run_dir']
    print(json.dumps(result, indent=2)[:2000])
else:
    print('skipped; command: python -m src.experiments --config', CONFIG_PATH, '--run smoke')
# Out:
# skipped; command: python -m src.experiments --config config/feasible_cassle_cifar100_smoke.yaml --run smoke

# %% [markdown]
# ## Inspect One Constrained Update

# %%
if RUN_TRAINING:
    from src.experiments import inspect_one_update
    inspection = inspect_one_update(CONFIG_PATH)
    print(json.dumps(inspection, indent=2))
else:
    print('skipped; command: python -m src.experiments --config', CONFIG_PATH, '--run inspect')
# Out:
# skipped; command: python -m src.experiments --config config/feasible_cassle_cifar100_smoke.yaml --run inspect

# %% [markdown]
# ## Selected Pilot Baselines

# %%
PILOT_CONFIG = 'config/feasible_cassle_cifar100_pilot.yaml'
PILOT_METHODS = ['offline_ssl', 'finetune', 'standard_cassle', 'crossfit_cassle', 'feasible_cassle']
if RUN_TRAINING:
    from src.experiments import run_pilot_selection
    result = run_pilot_selection(PILOT_CONFIG, methods=PILOT_METHODS)
    RESULT_DIR = result['run_dir']
    print(RESULT_DIR)
else:
    print('skipped; command: python -m src.experiments --config', PILOT_CONFIG, '--run pilot --methods', ' '.join(PILOT_METHODS))
# Out:
# skipped; command: python -m src.experiments --config config/feasible_cassle_cifar100_pilot.yaml --run pilot --methods offline_ssl finetune standard_cassle crossfit_cassle feasible_cassle

# %% [markdown]
# ## Load Result Files Without Retraining

# %%
def read_csv(path):
    with open(path) as f:
        return list(csv.DictReader(f))

def discover_runs(output_root=OUTPUT_ROOT):
    root = Path(output_root)
    if not root.exists():
        return []
    markers = ['smoke_summary.json', 'pilot_summary.json', 'accuracy_summary.csv']
    runs = []
    for marker in markers:
        runs.extend(p.parent for p in root.glob(f'*/*/{marker}'))
    return sorted(set(runs), key=lambda p: p.stat().st_mtime, reverse=True)

runs = discover_runs()
print('recent runs:')
for i, run in enumerate(runs[:10]):
    print(f'  [{i}] {run}')

if RESULT_DIR is None and runs:
    RESULT_DIR = str(runs[0])
    print('auto-selected latest RESULT_DIR:', RESULT_DIR)

if RESULT_DIR:
    root = Path(RESULT_DIR)
    if not root.exists():
        raise FileNotFoundError(f'RESULT_DIR does not exist: {root}')
    eval_logs = {p.parent.name: read_csv(p) for p in root.glob('*/eval_log.csv')}
    train_logs = {p.parent.name: read_csv(p) for p in root.glob('*/train_log.csv')}
    accuracy_summary = read_csv(root / 'accuracy_summary.csv') if (root / 'accuracy_summary.csv').exists() else []
    diagnostics_summary = read_csv(root / 'diagnostics_summary.csv') if (root / 'diagnostics_summary.csv').exists() else []
    figures = sorted((root / 'figures').glob('*.png')) if (root / 'figures').exists() else []
    print('loaded RESULT_DIR:', root)
    print('loaded eval logs:', sorted(eval_logs))
    print('accuracy rows:', len(accuracy_summary), 'diagnostic rows:', len(diagnostics_summary), 'figures:', len(figures))
else:
    eval_logs, train_logs, accuracy_summary, diagnostics_summary, figures = {}, {}, [], [], []
    print('No runs found. Run an experiment first or set RESULT_DIR manually.')
# Out:
# recent runs:
#   [0] outputs/feasible_cassle/feasible_cassle_cifar100_smoke/20260801-222211
#   [1] outputs/feasible_cassle/feasible_cassle_cifar100_smoke/20260801-220351
#   [2] outputs/feasible_cassle/feasible_cassle_cifar100_smoke/20260801-195602
#   [3] outputs/feasible_cassle/feasible_cassle_cifar100_smoke/20260801-205917
# auto-selected latest RESULT_DIR: outputs/feasible_cassle/feasible_cassle_cifar100_smoke/20260801-222211
# loaded RESULT_DIR: outputs/feasible_cassle/feasible_cassle_cifar100_smoke/20260801-222211
# loaded eval logs: ['finetune', 'learning_fwt_isolated']
# accuracy rows: 5 diagnostic rows: 0 figures: 5

# %% [markdown]
# ## Plots And Comparison Table

# %%
if RESULT_DIR and accuracy_summary:
    import pandas as pd
    import matplotlib.pyplot as plt
    from IPython.display import Image, display

    acc = pd.DataFrame(accuracy_summary)
    for col in ['task', 'accuracy', 'current_task_accuracy', 'avg_seen_accuracy', 'avg_forgetting_accuracy_drop', 'learning_forward_transfer_accuracy']:
        if col in acc:
            acc[col] = pd.to_numeric(acc[col], errors='coerce')
    task_rows = acc.dropna(subset=['task']) if 'task' in acc else acc

    display_cols = [c for c in ['method', 'task', 'evaluator', 'accuracy', 'current_task_accuracy', 'avg_seen_accuracy', 'avg_forgetting_accuracy_drop', 'learning_forward_transfer_accuracy'] if c in acc.columns]
    display(acc[display_cols].tail(20))

    for metric in ['current_task_accuracy', 'avg_seen_accuracy', 'avg_forgetting_accuracy_drop', 'learning_forward_transfer_accuracy']:
        if metric not in task_rows or task_rows[metric].dropna().empty:
            continue
        plt.figure(figsize=(7, 4))
        for method, group in task_rows.groupby('method', sort=False):
            group = group.sort_values('task')
            plt.plot(group['task'], group[metric], marker='o', label=method)
        plt.xlabel('task')
        plt.ylabel(metric)
        plt.title(metric.replace('_', ' ').title())
        plt.grid(alpha=0.25)
        plt.legend()
        plt.show()

    if figures:
        print('generated figures:')
        for fig in figures:
            print(fig.name)
            display(Image(filename=str(fig)))
elif RESULT_DIR:
    print('No accuracy_summary.csv found in', RESULT_DIR)
else:
    print('no result directory loaded')
# Out:
#      method  task evaluator  accuracy  current_task_accuracy  \
# 0  finetune     0    linear    7.8125               7.812500
# 1  finetune     1    linear    3.1250               2.941176
# 2  finetune     2    linear    1.5625               4.545455
# 3  finetune     3    linear    0.0000               0.000000
# 4  finetune     4    linear    1.5625               0.000000
#
#    avg_seen_accuracy  avg_forgetting_accuracy_drop  \
# 0           7.812500                           NaN
# 1           3.137255                           0.0
# 2           1.515152                           0.0
# 3           0.000000                           0.0
# 4           1.818182                           0.0
#
#    learning_forward_transfer_accuracy
# 0                                 NaN
# 1                           -0.183824
# 2                           -0.142045
# 3                           -4.687500
# 4                           -1.562500
# generated figures:
# avg_forgetting.png
# ...

# %% [markdown]
# ## Go/No-Go Assessment

# %%
if RESULT_DIR and accuracy_summary:
    print('Loaded:', RESULT_DIR)
    print('Assess: current-task accuracy, tuned gamma comparison, corrected forgetting, learning-FWT, conflict rate, active rate, correction ratio, and shared task-1 checkpoint.')
    if diagnostics_summary:
        try:
            import pandas as pd
            display(pd.DataFrame(diagnostics_summary))
        except Exception:
            print(diagnostics_summary[:3])
else:
    print('No assessment without completed pilot results. Smoke runs do not validate the research hypothesis.')
# Out:
# Loaded: outputs/feasible_cassle/feasible_cassle_cifar100_smoke/20260801-222211
# Assess: current-task accuracy, tuned gamma comparison, corrected forgetting, learning-FWT, conflict rate, active rate, correction ratio, and shared task-1 checkpoint.
